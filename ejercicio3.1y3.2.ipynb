# %% [markdown]
# #### Reemplazo de valores nulos de variables categoricas a 'Others'

# %% [markdown]
# #### 3.1, 3.2 Transformacion de variables categoricas

# %%
### Seleccion de columnas categoricas
categorical = [ 'Attrition_Flag', 'Customer_Age', 'Gender',
        'Education_Level', 'Marital_Status',
        'Card_Category']

# %%
categorical
dataset1.shape
# Out:
# (10127, 23)

# %%
target = .95

valid_columns = []
columns_many_level = []
columns_one_level = []

for c_ in categorical:
   x = dataset1.loc[ :, [c_]].drop_duplicates()
   unique_values = x.shape[0]

   if unique_values == 1:
    columns_one_level.append(c_)
   elif (unique_values/dataset1.shape[0]) > target :
      columns_many_level.append(c_)
   else:
      valid_columns.append(c_)

# %%
categorical
# Out:
# ['Attrition_Flag',
#  'Customer_Age',
#  'Gender',
#  'Education_Level',
#  'Marital_Status',
#  'Card_Category']

# %% [markdown]
# #### Tratamiento columna 'Customer_Age' check

# %%
freq_customer_age = dataset1.groupby(["Customer_Age"], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_customer_age.columns = freq_customer_age.columns.droplevel(1)
freq_customer_age['Percentage'] = freq_customer_age['CLIENTNUM'] / dataset1.shape[0]
freq_customer_age['Customr_Age'] = 'Others'
freq_customer_age['Customr_Age'] = freq_customer_age.apply(lambda r: r['Customer_Age'] if r['Percentage'] > 0.0303 else 'Others', axis=1)
freq_customer_age.sort_values(['Percentage'], ascending=False)
freq_customer_age = freq_customer_age.loc[:, ['Customer_Age', 'Customr_Age']]
freq_customer_age.to_csv('freq_customer_age.csv', index=False)
dataset1.merge(freq_customer_age, on='Customer_Age', how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Customr_Age
# 0               45
# 1               49
# 2               51
# 3               40
# 4               40
# ...            ...
# 10122           50
# 10123           41
# 10124           44
# 10125       Others
# 10126           43
#
# [10127 rows x 24 columns]

# %% [markdown]
# #### Tratamiento columna 'Card_Category'

# %%
freq_card = dataset1.groupby(["Card_Category"], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_card.columns = freq_card.columns.droplevel(1)
freq_card['Percentage'] = freq_card['CLIENTNUM'] / dataset1.shape[0]
freq_card['Card_Catg'] = 'Others'
freq_card['Card_Catg'] = freq_card.apply(lambda r: r['Card_Category'] if r['Percentage'] > 0.0303 else 'Others', axis=1)
freq_card.sort_values(['Percentage'], ascending=False)
freq_card = freq_card.loc[ : , ['Card_Category', 'Card_Catg' ]]
freq_card.to_csv('freq_card.csv', index=False)
dataset1.merge(freq_card, on=['Card_Category'], how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Card_Catg
# 0           Blue
# 1           Blue
# 2           Blue
# 3           Blue
# 4           Blue
# ...          ...
# 10122       Blue
# 10123       Blue
# 10124       Blue
# 10125       Blue
# 10126     Silver
#
# [10127 rows x 24 columns]

# %% [markdown]
# #### Tratamiento columna 'Education_Level' check

# %%
freq_education = dataset1.groupby(["Education_Level"], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_education.columns = freq_education.columns.droplevel(1)
freq_education['Percentage'] = freq_education['CLIENTNUM'] / dataset1.shape[0]
freq_education['Edu_Lvl'] = 'Others'
freq_education['Edu_Lvl'] = freq_education.apply(lambda r: r['Education_Level'] if r['Percentage'] > 0.0303 else 'Others', axis=1)
freq_education.sort_values(['Percentage'], ascending=False)
freq_education = freq_education.loc[ : , ['Education_Level', 'Edu_Lvl' ]]
freq_education.to_csv('freq_education.csv', index=False)
dataset1.merge(freq_education, on=['Education_Level'], how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#            Edu_Lvl
# 0      High School
# 1         Graduate
# 2         Graduate
# 3      High School
# 4       Uneducated
# ...            ...
# 10122     Graduate
# 10123       Others
# 10124  High School
# 10125     Graduate
# 10126     Graduate
#
# [10127 rows x 24 columns]

# %% [markdown]
# #### Tratamiento columna 'Gender' check

# %%
freq_gender = dataset1.groupby(["Gender"], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_gender.columns = freq_gender.columns.droplevel(1)
freq_gender['Percentage'] = freq_gender['CLIENTNUM'] / dataset1.shape[0]
freq_gender['Gender_T'] = 'Others'
freq_gender['Gender_T'] = freq_gender.apply(lambda r: r['Gender'] if r['Percentage'] > 0.1 else 'Others', axis=1)
freq_gender.sort_values(['Percentage'], ascending=False)
freq_gender = freq_gender.loc[ : , ['Gender', 'Gender_T' ]]
freq_gender.to_csv('freq_gender.csv', index=False)
dataset1.merge(freq_gender, on=['Gender'], how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Gender_T
# 0             M
# 1             F
# 2             M
# 3             F
# 4             M
# ...         ...
# 10122         M
# 10123         M
# 10124         F
# 10125         M
# 10126         F
#
# [10127 rows x 24 columns]

# %% [markdown]
# #### Tratamiento columna 'Marital_Status' check

# %%
freq_marital = dataset1.groupby(['Marital_Status'], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_marital.columns = freq_marital.columns.droplevel(1)
freq_marital['Percentage'] = freq_marital['CLIENTNUM'] / dataset1.shape[0]
freq_marital['Marital_St'] = 'Others'
freq_marital['Marital_St'] = freq_marital.apply(lambda r: r['Marital_Status'] if r['Percentage'] > 0.389 else 'Others', axis=1)
freq_marital.sort_values(['Percentage'], ascending=False)
freq_marital = freq_marital.loc[ : , ['Marital_Status', 'Marital_St' ]]
freq_marital.to_csv('freq_marital.csv', index=False)
dataset1.merge(freq_marital, on=['Marital_Status'], how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#        Marital_St
# 0         Married
# 1          Single
# 2         Married
# 3          Others
# 4         Married
# ...           ...
# 10122      Single
# 10123      Others
# 10124     Married
# 10125      Others
# 10126     Married
#
# [10127 rows x 24 columns]

# %% [markdown]
# #### Tratamiento columna 'Attrition_Flag' check

# %%
freq_attr_flag = dataset1.groupby(["Attrition_Flag"], as_index=False).agg({"CLIENTNUM": ["count"]})
freq_attr_flag.columns = freq_attr_flag.columns.droplevel(1)
freq_attr_flag['Percentage'] = freq_attr_flag['CLIENTNUM'] / dataset1.shape[0]
freq_attr_flag['Attr_flag'] = 'Others'
freq_attr_flag['Attr_flag'] = freq_attr_flag.apply(lambda r: r['Attrition_Flag'] if r['Percentage'] > 0.1 else 'Others', axis=1)
freq_attr_flag.sort_values(['Percentage'], ascending=False)
freq_attr_flag = freq_attr_flag.loc[:, ['Attrition_Flag', 'Attr_flag']]
freq_attr_flag.to_csv('freq_attr_flag.csv', index=False)
dataset1.merge(freq_attr_flag, on='Attrition_Flag', how='left')
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# 2            Graduate        Married    $80K - $120K          Blue
# 3         High School         Others  Less than $40K          Blue
# 4          Uneducated        Married     $60K - $80K          Blue
# ...               ...            ...             ...           ...
# 10122        Graduate         Single     $40K - $60K          Blue
# 10123          Others       Divorced     $40K - $60K          Blue
# 10124     High School        Married  Less than $40K          Blue
# 10125        Graduate         Others     $40K - $60K          Blue
# 10126        Graduate        Married  Less than $40K        Silver
#
#        Months_on_book  ...  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0                  39  ...                  777          11914.0
# 1                  44  ...                  864           7392.0
# 2                  36  ...                    0           3418.0
# 3                  34  ...                 2517            796.0
# 4                  21  ...                    0           4716.0
# ...               ...  ...                  ...              ...
# 10122              40  ...                 1851           2152.0
# 10123              25  ...                 2186           2091.0
# 10124              36  ...                    0           5409.0
# 10125              36  ...                    0           5281.0
# 10126              25  ...                 1961           8427.0
#
#        Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  Total_Trans_Ct  \
# 0                     1.335             1144              42
# 1                     1.541             1291              33
# 2                     2.594             1887              20
# 3                     1.405             1171              20
# 4                     2.175              816              28
# ...                     ...              ...             ...
# 10122                 0.703            15476             117
# 10123                 0.804             8764              69
# 10124                 0.819            10291              60
# 10125                 0.535             8395              62
# 10126                 0.703            10294              61
#
#        Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# 0                    1.625                  0.061
# 1                    3.714                  0.105
# 2                    2.333                  0.000
# 3                    2.333                  0.760
# 4                    2.500                  0.000
# ...                    ...                    ...
# 10122                0.857                  0.462
# 10123                0.683                  0.511
# 10124                0.818                  0.000
# 10125                0.722                  0.000
# 10126                0.649                  0.189
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1  \
# 0                                               0.000093
# 1                                               0.000057
# 2                                               0.000021
# 3                                               0.000134
# 4                                               0.000022
# ...                                                  ...
# 10122                                           0.000191
# 10123                                           0.995270
# 10124                                           0.997880
# 10125                                           0.996710
# 10126                                           0.996620
#
#        Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2  \
# 0                                               0.999910
# 1                                               0.999940
# 2                                               0.999980
# 3                                               0.999870
# 4                                               0.999980
# ...                                                  ...
# 10122                                           0.999810
# 10123                                           0.004729
# 10124                                           0.002118
# 10125                                           0.003294
# 10126                                           0.003377
#
#                Attr_flag
# 0      Existing Customer
# 1      Existing Customer
# 2      Existing Customer
# 3      Existing Customer
# 4      Existing Customer
# ...                  ...
# 10122  Existing Customer
# 10123  Attrited Customer
# 10124  Attrited Customer
# 10125  Attrited Customer
# 10126  Attrited Customer
#
# [10127 rows x 24 columns]

# %%
dataset1.shape
# Out:
# (10127, 23)
